# %%
import pandas as pd
df=pd.read_csv("D:\\csv file\\stock_data.csv")
df
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1       NaN    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA  NaN            NaN       NaN     0.0     ratan tata
# 5     NaN  NaN            NaN       NaN     NaN            NaN

# %%
df.fillna(2)
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1         2    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA    2              2         2     0.0     ratan tata
# 5       2    2              2         2     2.0              2

# %%
df.fillna(0)
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1         0    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA    0              0         0     0.0     ratan tata
# 5       0    0              0         0     0.0              0

# %%
df.fillna({'Date':0,'eps':0,'people':'none'})
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1       NaN    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA    0              0       NaN     0.0     ratan tata
# 5     NaN    0              0       NaN     NaN           none

# %%
df.fillna(method='ffill')
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1       484    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA  Yes  not available  no value     0.0     ratan tata
# 5    TATA  Yes  not available  no value     0.0     ratan tata

# %%
df=pd.read_csv("D:\\csv file\\stock_data.csv")

df.fillna(method='bfill')
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1  no value    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA  yes            NaN        90     0.0     ratan tata
# 5     NaN  yes            NaN        90     NaN            NaN

# %%
df.fillna(3,limit=1)
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1         3    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA    3              3       NaN     0.0     ratan tata
# 5       3  yes            NaN        90     3.0              3

# %%
df.fillna(3,limit=2)
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1         3    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA    3              3         3     0.0     ratan tata
# 5       3  yes              3        90     3.0              3

# %%
df.fillna(method='ffill',limit=1)
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1       484    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA  Yes  not available  no value     0.0     ratan tata
# 5    TATA  yes            NaN        90     0.0     ratan tata

# %%
df.fillna(method='ffill',limit=2)
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1       484    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA  Yes  not available  no value     0.0     ratan tata
# 5    TATA  yes  not available        90     0.0     ratan tata

# %%
df.fillna(3,inplace=True)
df
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1         3    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA    3              3         3     0.0     ratan tata
# 5       3  yes              3        90     3.0              3

# %%
df.fillna('ffill',inplace=True)
df
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1         3    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA    3              3         3     0.0     ratan tata
# 5       3  yes              3        90     3.0              3
