# %%
import pandas as pd

# %%
df=pd.read_csv("D:\\csv file\\stock_data.csv")
df
# Out:
#   tickers Date            eps   revenue  price         people
# 0   GOOGL  Yes          27.82        87    845     larry page
# 1     WMT   No           4.61       484     65           n.a.
# 2    MSFT  Yes             -1       NaN     64     bill gates
# 3    RIL   Yes  not available  no value   1023  mukesh ambani
# 4    TATA   No            5.6       NaN      0     ratan tata

# %%
df.isnull()
# Out:
#    tickers   Date    eps  revenue  price  people
# 0    False  False  False    False  False   False
# 1    False  False  False    False  False   False
# 2    False  False  False     True  False   False
# 3    False  False  False    False  False   False
# 4    False  False  False     True  False   False

# %%
df.isnull().sum()
# Out:
# tickers    0
# Date       0
# eps        0
# revenue    2
# price      0
# people     0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 2

# %%
df.notnull()
# Out:
#    tickers  Date   eps  revenue  price  people
# 0     True  True  True     True   True    True
# 1     True  True  True     True   True    True
# 2     True  True  True    False   True    True
# 3     True  True  True     True   True    True
# 4     True  True  True    False   True    True

# %%
df.notnull().sum()
# Out:
# tickers    5
# Date       5
# eps        5
# revenue    3
# price      5
# people     5
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 28

# %%
##series
import numpy as np

# %%
sr=pd.Series([1,2,3,np.nan,4,np.nan])
sr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %%
sr.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
sr.notnull().sum()
# Out:
# 4

# %% [markdown]
# # using dropna() method

# %%
import pandas as pd
df=pd.read_csv("D:\\csv file\\stock_data.csv")
df
# Out:
#   tickers Date            eps   revenue  price         people
# 0   GOOGL  Yes          27.82        87    845     larry page
# 1     WMT   No           4.61       484     65           n.a.
# 2    MSFT  Yes             -1       NaN     64     bill gates
# 3    RIL   Yes  not available  no value   1023  mukesh ambani
# 4    TATA   No            5.6       NaN      0     ratan tata

# %%
df.dropna()
# Out:
#   tickers Date            eps   revenue  price         people
# 0   GOOGL  Yes          27.82        87    845     larry page
# 1     WMT   No           4.61       484     65           n.a.
# 3    RIL   Yes  not available  no value   1023  mukesh ambani

# %%
df.dropna(axis=1)
# Out:
#   tickers Date            eps  price         people
# 0   GOOGL  Yes          27.82    845     larry page
# 1     WMT   No           4.61     65           n.a.
# 2    MSFT  Yes             -1     64     bill gates
# 3    RIL   Yes  not available   1023  mukesh ambani
# 4    TATA   No            5.6      0     ratan tata

# %%
df=pd.read_csv("D:\\csv file\\stock_data.csv")
df
# Out:
#   tickers Date            eps   revenue  price         people
# 0   GOOGL  Yes          27.82        87    845     larry page
# 1     WMT   No           4.61       484     65           n.a.
# 2    MSFT  Yes             -1       NaN     64     bill gates
# 3    RIL   Yes  not available  no value   1023  mukesh ambani
# 4    TATA  NaN            NaN       NaN      0     ratan tata

# %%
df.dropna(axis=1)
# Out:
#   tickers  price         people
# 0   GOOGL    845     larry page
# 1     WMT     65           n.a.
# 2    MSFT     64     bill gates
# 3    RIL    1023  mukesh ambani
# 4    TATA      0     ratan tata

# %%
df.dropna(how='any')
# Out:
#   tickers Date            eps   revenue  price         people
# 0   GOOGL  Yes          27.82        87    845     larry page
# 1     WMT   No           4.61       484     65           n.a.
# 3    RIL   Yes  not available  no value   1023  mukesh ambani

# %%
df.dropna(how='all')
# Out:
#   tickers Date            eps   revenue  price         people
# 0   GOOGL  Yes          27.82        87    845     larry page
# 1     WMT   No           4.61       484     65           n.a.
# 2    MSFT  Yes             -1       NaN     64     bill gates
# 3    RIL   Yes  not available  no value   1023  mukesh ambani
# 4    TATA  NaN            NaN       NaN      0     ratan tata

# %%
df=pd.read_csv("D:\\csv file\\stock_data.csv")
df
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1       NaN    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA  NaN            NaN       NaN     0.0     ratan tata
# 5     NaN  NaN            NaN       NaN     NaN            NaN

# %%
df.dropna(axis=0,how='all')
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1       NaN    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA  NaN            NaN       NaN     0.0     ratan tata

# %%
df.dropna(thresh=4)
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1       NaN    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani

# %%
df.dropna(subset=['revenue'])## drop roew with na value
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani

# %%
## drop row with na values.
df.dropna(inplace=True)
df
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani

# %%
df=pd.read_csv("D:\\csv file\\stock_data.csv")

df.dropna(inplace=False)
df
# Out:
#   tickers Date            eps   revenue   price         people
# 0   GOOGL  Yes          27.82        87   845.0     larry page
# 1     WMT   No           4.61       484    65.0           n.a.
# 2    MSFT  Yes             -1       NaN    64.0     bill gates
# 3    RIL   Yes  not available  no value  1023.0  mukesh ambani
# 4    TATA  NaN            NaN       NaN     0.0     ratan tata
# 5     NaN  NaN            NaN       NaN     NaN            NaN
