# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\csv file\\class.csv')
df
# Out:
#    Student id  class  study hrs  social media usein hrs  Unnamed: 4  \
# 0        1001     10          3                       4         NaN
# 1        1002     12          4                       6         NaN
# 2        1003     10          4                       8         NaN
# 3        1004     11          2                       5         NaN
# 4        1005      9          2                       7         NaN
#
#    Unnamed: 5  percentage  Unnamed: 7
# 0         NaN          70         NaN
# 1         NaN          80         NaN
# 2         NaN          90         NaN
# 3         NaN          70         NaN
# 4         NaN          56         NaN

# %%
df.loc[1]
# Out:
# Student id                1002.0
# class                       12.0
# study hrs                    4.0
# social media usein hrs       6.0
# Unnamed: 4                   NaN
# Unnamed: 5                   NaN
# percentage                  80.0
# Unnamed: 7                   NaN
# Name: 1, dtype: float64

# %%
df.loc[2]
# Out:
# Student id                1003.0
# class                       10.0
# study hrs                    4.0
# social media usein hrs       8.0
# Unnamed: 4                   NaN
# Unnamed: 5                   NaN
# percentage                  90.0
# Unnamed: 7                   NaN
# Name: 2, dtype: float64

# %%
df.loc[[1,2,3,4]]
# Out:
#    Student id  class  study hrs  social media usein hrs  Unnamed: 4  \
# 1        1002     12          4                       6         NaN
# 2        1003     10          4                       8         NaN
# 3        1004     11          2                       5         NaN
# 4        1005      9          2                       7         NaN
#
#    Unnamed: 5  percentage  Unnamed: 7
# 1         NaN          80         NaN
# 2         NaN          90         NaN
# 3         NaN          70         NaN
# 4         NaN          56         NaN

# %%
df.loc[df['Student id'] > 1002,'percentage']
# Out:
# 2    90
# 3    70
# 4    56
# Name: percentage, dtype: int64

# %%
df.loc[:]
# Out:
#    Student id  class  study hrs  social media usein hrs  Unnamed: 4  \
# 0        1001     10          3                       4         NaN
# 1        1002     12          4                       6         NaN
# 2        1003     10          4                       8         NaN
# 3        1004     11          2                       5         NaN
# 4        1005      9          2                       7         NaN
#
#    Unnamed: 5  percentage  Unnamed: 7
# 0         NaN          70         NaN
# 1         NaN          80         NaN
# 2         NaN          90         NaN
# 3         NaN          70         NaN
# 4         NaN          56         NaN

# %%
df.loc[3:]
# Out:
#    Student id  class  study hrs  social media usein hrs  Unnamed: 4  \
# 3        1004     11          2                       5         NaN
# 4        1005      9          2                       7         NaN
#
#    Unnamed: 5  percentage  Unnamed: 7
# 3         NaN          70         NaN
# 4         NaN          56         NaN

# %%
df.loc[[True,False,False,True,True]]
# Out:
#    Student id  class  study hrs  social media usein hrs  Unnamed: 4  \
# 0        1001     10          3                       4         NaN
# 3        1004     11          2                       5         NaN
# 4        1005      9          2                       7         NaN
#
#    Unnamed: 5  percentage  Unnamed: 7
# 0         NaN          70         NaN
# 3         NaN          70         NaN
# 4         NaN          56         NaN

# %%
df
# Out:
#             Student id  class  study hrs  social media usein hrs  Unnamed: 4  \
# 0                 1001     10          3                       4         NaN
# 1                 1002     12          4                       6         NaN
# 2                 1003     10          4                       8         NaN
# 3                 1004     11          2                       5         NaN
# 4                 1005      9          2                       7         NaN
# percentage          70     70         70                      70        70.0
#
#             Unnamed: 5  percentage  Unnamed: 7
# 0                  NaN          70         NaN
# 1                  NaN          80         NaN
# 2                  NaN          90         NaN
# 3                  NaN          70         NaN
# 4                  NaN          56         NaN
# percentage        70.0          70        70.0

# %% [markdown]
# # ILOC[] METHOD AND ITS DATATYPES

# %%
df=pd.read_csv('D:\\csv file\\class.csv')
df
# Out:
#    Student id  class  study hrs  social media usein hrs  Unnamed: 4  \
# 0        1001     10          3                       4         NaN
# 1        1002     12          4                       6         NaN
# 2        1003     10          4                       8         NaN
# 3        1004     11          2                       5         NaN
# 4        1005      9          2                       7         NaN
#
#    Unnamed: 5  percentage  Unnamed: 7
# 0         NaN          70         NaN
# 1         NaN          80         NaN
# 2         NaN          90         NaN
# 3         NaN          70         NaN
# 4         NaN          56         NaN

# %%
df.iloc[0]
# Out:
# Student id                1001.0
# class                       10.0
# study hrs                    3.0
# social media usein hrs       4.0
# Unnamed: 4                   NaN
# Unnamed: 5                   NaN
# percentage                  70.0
# Unnamed: 7                   NaN
# Name: 0, dtype: float64

# %%
df.iloc[4]
# Out:
# Student id                1005.0
# class                        9.0
# study hrs                    2.0
# social media usein hrs       7.0
# Unnamed: 4                   NaN
# Unnamed: 5                   NaN
# percentage                  56.0
# Unnamed: 7                   NaN
# Name: 4, dtype: float64

# %%
df.iloc[[0,3,4]]
# Out:
#    Student id  class  study hrs  social media usein hrs  Unnamed: 4  \
# 0        1001     10          3                       4         NaN
# 3        1004     11          2                       5         NaN
# 4        1005      9          2                       7         NaN
#
#    Unnamed: 5  percentage  Unnamed: 7
# 0         NaN          70         NaN
# 3         NaN          70         NaN
# 4         NaN          56         NaN

# %%
df.iloc[:,6:7]
# Out:
#    percentage
# 0          70
# 1          80
# 2          90
# 3          70
# 4          56

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df.iloc[[True, False, True,False,False]]
# Out:
#    Student id  class  study hrs  social media usein hrs  Unnamed: 4  \
# 0        1001     10          3                       4         NaN
# 2        1003     10          4                       8         NaN
#
#    Unnamed: 5  percentage  Unnamed: 7
# 0         NaN          70         NaN
# 2         NaN          90         NaN

# %%
 df.iloc[lambda percentage : df.index % 2 == 0]
# Out:
#    Student id  class  study hrs  social media usein hrs  Unnamed: 4  \
# 0        1001     10          3                       4         NaN
# 2        1003     10          4                       8         NaN
# 4        1005      9          2                       7         NaN
#
#    Unnamed: 5  percentage  Unnamed: 7
# 0         NaN          70         NaN
# 2         NaN          90         NaN
# 4         NaN          56         NaN

# %%
df.dtypes
# Out:
# Student id                  int64
# class                       int64
# study hrs                   int64
# social media usein hrs      int64
# Unnamed: 4                float64
# Unnamed: 5                float64
# percentage                  int64
# Unnamed: 7                float64
# dtype: object
