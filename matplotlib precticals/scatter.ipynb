# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('D:\\csv file\\bengaluru_house_prices.csv')
df.shape
# Out:
# (13320, 9)

# %%
df=pd.read_csv('D:\\csv file\\bengaluru_house_prices.csv',nrows=1000)
df.shape
df
# Out:
#                 area_type   availability                  location       size  \
# 0    Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1              Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2          Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3    Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4    Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# ..                    ...            ...                       ...        ...
# 995        Built-up  Area  Ready To Move                     Hoodi      2 BHK
# 996            Plot  Area  Ready To Move             Chikkabanavar  1 Bedroom
# 997            Plot  Area         18-Aug                      ITPL  3 Bedroom
# 998        Built-up  Area  Ready To Move         Somasundara Palya      2 BHK
# 999  Super built-up  Area  Ready To Move               Hegde Nagar      3 BHK
#
#      society total_sqft  bath  balcony   price
# 0    Coomee        1056   2.0      1.0   39.07
# 1    Theanmp       2600   5.0      3.0  120.00
# 2        NaN       1440   2.0      3.0   62.00
# 3    Soiewre       1521   3.0      1.0   95.00
# 4        NaN       1200   2.0      1.0   51.00
# ..       ...        ...   ...      ...     ...
# 995  Goeur G       1425   2.0      2.0   80.00
# 996      NaN       1200   1.0      0.0   20.00
# 997      NaN       1200   3.0      1.0   56.12
# 998  Abeesmi       1255   2.0      2.0   67.00
# 999  SoisoCa    2112.95   4.0      2.0  145.00
#
# [1000 rows x 9 columns]

# %%
x=df['price']
y=df['balcony']
plt.scatter(x,y)
plt.xlabel('price of flat',fontsize=18)
plt.ylabel('balcony',fontsize=18)
plt.title('bengaluru_house_prices',fontsize=18)
# Out:
# Text(0.5, 1.0, 'bengaluru_house_prices')

# %%
x=df['price']
y=df['balcony']
plt.figure(figsize=(16,9))
plt.scatter(x,y,c='r',s=10,edgecolors='blue',marker='*',alpha=0.5,linewidth=10)
plt.xlabel('price of flat',fontsize=18)
plt.ylabel('balcony',fontsize=18)
plt.title('bengaluru_house_prices',fontsize=18)
plt.figure(figsize=(16,9))

# %%
x=df['price']
y=df['balcony']
plt.figure(figsize=(16,9))
plt.scatter(x,y,c='r',s=10,edgecolors='blue',marker='*',alpha=0.5,linewidth=10)
plt.scatter(x,df['total_sqft'],c='k',s=10,edgecolors='blue',marker='<',alpha=0.5,linewidth=10)

plt.xlabel('price of flat',fontsize=18)
plt.ylabel('balcony',fontsize=18)
plt.title('bengaluru_house_prices',fontsize=18)
# Out:
# Text(0.5, 1.0, 'bengaluru_house_prices')
